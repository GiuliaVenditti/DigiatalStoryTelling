# %%
# import needed
import pandas as pd # data processing
import pandas_profiling as pp
import numpy as np # linear algebra
import pprint #indet json 
import requests #make http requests
from qwikidata.sparql  import return_sparql_query_results #return sparql results

# %%
df_netflix = pd.read_csv('originalDataset/netflix_titles.csv')
df_amazon = pd.read_csv('originalDataset/amazon_prime_titles.csv')
print(len(df_netflix))
print(len(df_amazon))
# Out:
# 8807
# 9668

# %%
df_netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df_amazon.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...

# %%
df_netflix["date_added"] = pd.to_datetime(df_netflix['date_added']) #turn dates into dates


""" df_netflix['month_added']=df_netflix['date_added'].dt.month
df_netflix['month_name_added']=df_netflix['date_added'].dt.month_name() #add separate column 4 year date month(?)
df_netflix['year_added'] = df_netflix['date_added'].dt.year
 """
df_netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
netflix = df_netflix.query("type == 'Movie'") #keep only movies
netflix.reset_index(level=None, drop=True, inplace=True, col_level=0, col_fill='')
netflix.head(3)
# Out:
#   show_id   type                             title  \
# 0      s1  Movie              Dick Johnson Is Dead
# 1      s7  Movie  My Little Pony: A New Generation
# 2      s8  Movie                           Sankofa
#
#                         director  \
# 0                Kirsten Johnson
# 1  Robert Cullen, José Luis Ucha
# 2                   Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 1  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country date_added  release_year  \
# 0                                      United States 2021-09-25          2020
# 1                                                NaN 2021-09-24          2021
# 2  United States, Ghana, Burkina Faso, United Kin... 2021-09-24          1993
#
#   rating duration                                         listed_in  \
# 0  PG-13   90 min                                     Documentaries
# 1     PG   91 min                          Children & Family Movies
# 2  TV-MA  125 min  Dramas, Independent Movies, International Movies
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  Equestria's divided. But a bright-eyed hero be...
# 2  On a photo shoot in Ghana, an American model s...

# %%
#QUERY!!!!!!!!!!!!!

'''SELECT ?film ?film_label ?director ?director_label ?dir_gen ?dir_gen_label ?distributor ?distributor_label ?review_score
WHERE
{
  # ?film wdt:P31 wd:Q11424 .
  # ?film rdfs:label "Zubaan"@en .
  # ?film rdfs:label ?film_label .
  FILTER(lang(?film_label) = 'en')
  # ?film wdt:P57 ?director . 
  # ?director rdfs:label ?director_label .    
  FILTER(lang(?director_label) = 'en')
  # ?director wdt:P21 ?dir_gen . 
  # ?dir_gen rdfs:label ?dir_gen_label .
  FILTER(lang(?dir_gen_label) = 'en')
  # ?film wdt:P750 ?distributor . 
  # ?distributor rdfs:label ?distributor_label .
  FILTER(lang(?distributor_label) = 'en')
  # ?film wdt:P444 ?review_score .
}'''
# Out:
# 'SELECT ?film ?film_label ?director ?director_label ?dir_gen ?dir_gen_label ?distributor ?distributor_label ?review_score\nWHERE\n{\n  ?film wdt:P31 wd:Q11424 .\n  ?film rdfs:label "Zubaan"@en .\n  ?film rdfs:label ?film_label .\n  FILTER(lang(?film_label) = \'en\')\n  ?film wdt:P57 ?director . \n  ?director rdfs:label ?director_label .    \n  FILTER(lang(?director_label) = \'en\')\n  ?director wdt:P21 ?dir_gen . \n  ?dir_gen rdfs:label ?dir_gen_label .\n  FILTER(lang(?dir_gen_label) = \'en\')\n  ?film wdt:P750 ?distributor . \n  ?distributor rdfs:label ?distributor_label .\n  FILTER(lang(?distributor_label) = \'en\')\n  ?film wdt:P444 ?review_score .\n}'

# %%
p = pprint.PrettyPrinter(indent=1)
# funzia piu o mno come una ricerca su wikidata
API_WD = "https://www.wikidata.org/w/api.php"
params = {
    'action': 'wbsearchentities',# <------------ web search from wikidata
    'format': 'json',
    'language': 'en',
    'search': 'Dick Johnson Is Dead' # the query string
}

# query wd API    
r = requests.get(API_WD, params = params).json() 
p.pprint(r)
# Out:
# {'search': [{'concepturi': 'http://www.wikidata.org/entity/Q84366622',
#              'description': '2020 documentary film by Kirsten Johnson',
#              'display': {'description': {'language': 'en',
#                                          'value': '2020 documentary film by '
#                                                   'Kirsten Johnson'},
#                          'label': {'language': 'en',
#                                    'value': 'Dick Johnson Is Dead'}},
#              'id': 'Q84366622',
#              'label': 'Dick Johnson Is Dead',
#              'match': {'language': 'en',
#                        'text': 'Dick Johnson Is Dead',
#                        'type': 'label'},
#              'pageid': 83667587,
#              'repository': 'wikidata',
#              'title': 'Q84366622',
#              'url': '//www.wikidata.org/wiki/Q84366622'}],
#  'searchinfo': {'search': 'Dick Johnson Is Dead'},
#  'success': 1}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON #questo serve a vedere la struttura delle risposte
import ssl

p = pprint.PrettyPrinter(indent=1)
ssl._create_default_https_context = ssl._create_unverified_context #????? ceracare poi (lezioni daquino)

# get the endpoint API
wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql" #<---------- Non è l'endpoint, stiamo fetchando della documentazione di qualche tipo

# prepare the query : 10 random triples
my_SPARQL_query = """
SELECT *
WHERE {?s ?p ?o}
LIMIT 10
"""

# set the endpoint 
sparql_wd = SPARQLWrapper(wikidata_endpoint)
# set the query
sparql_wd.setQuery(my_SPARQL_query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

p.pprint(results)
# Out:
# {'head': {'vars': ['s', 'p', 'o']},
#  'results': {'bindings': [{'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:29Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:31Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:32Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:33Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:34Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:35Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:37Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:39Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:40Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}},
#                           {'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#                                  'type': 'literal',
#                                  'value': '2021-09-24T23:11:41Z'},
#                            'p': {'type': 'uri',
#                                  'value': 'http://schema.org/dateModified'},
#                            's': {'type': 'uri',
#                                  'value': 'http://wikiba.se/ontology#Dump'}}]}}

# %%
import time
for x in range(6):
  if x == 3:
    time.sleep(5)
    print(x)
  else:
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
title = list(netflix['title']) #printa una lista di titoli da netflix
#print(title[0:100], title[100:200])
#print(title[0:100], title[100:200])
print(len(title))
# Out:
# 6131

# %%
#print(film)
ciccio_prova = title[0:20] 
print(ciccio_prova)
# Out:
# ['Dick Johnson Is Dead', 'My Little Pony: A New Generation', 'Sankofa', 'The Starling', 'Je Suis Karl', 'Confessions of an Invisible Girl', "Europe's Most Dangerous Man: Otto Skorzeny in Spain", 'Intrusion', 'Avvai Shanmughi', 'Go! Go! Cory Carson: Chrissy Takes the Wheel', 'Jeans', 'Minsara Kanavu', 'Grown Ups', 'Dark Skies', 'Paranoia', 'Ankahi Kahaniya', 'The Father Who Moves Mountains', 'The Stronghold', 'Birth of the Dragon', 'Jaws']

# %%
""" print("film1 should be []")
print(film) """


p = pprint.PrettyPrinter(indent=1)

def wikidata_reconciliation(query):

    oneundred_ttls = [ciccio_prova[x:x + 100] for x in range(0, len(ciccio_prova), 100)]
    for i in range(0, len(oneundred_ttls)):
        time.sleep(25)
        

        ssl._create_default_https_context = ssl._create_unverified_context
    
    
    # get the endpoint API
        wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
        """ print("query = title[0:2]")
        print(query)
        print("film should be []")
        print(film) """

        for x in oneundred_ttls[i]:
            print(x)
            my_SPARQL_query = """
            SELECT ?film ?film_label ?director ?director_label ?dir_gen ?dir_gen_label ?distributor ?distributor_label ?review_score
            WHERE
            {
            # ?film wdt:P31 wd:Q11424 .
            # ?film rdfs:label """+'"'+ x +'"' +"""@en .
            # ?film rdfs:label ?film_label .
            FILTER(lang(?film_label) = 'en')
            # ?film wdt:P57 ?director . 
            # ?director rdfs:label ?director_label .    
            FILTER(lang(?director_label) = 'en')
            # ?director wdt:P21 ?dir_gen . 
            # ?dir_gen rdfs:label ?dir_gen_label .
            FILTER(lang(?dir_gen_label) = 'en')
            # ?film wdt:P750 ?distributor . 
            # ?distributor rdfs:label ?distributor_label .
            FILTER(lang(?distributor_label) = 'en')
            # ?film wdt:P444 ?review_score .
            }
            """
            # set the endpoint 
            sparql_wd = SPARQLWrapper(wikidata_endpoint)
            # set the query
            sparql_wd.setQuery(my_SPARQL_query)
            # set the returned format
            sparql_wd.setReturnFormat(JSON)
            # get the results
            
            results = sparql_wd.query().convert()
            response = requests.head(wikidata_endpoint)
            """if response.status_code == 429:
                print("riproviamo")
                time.sleep(int(response.headers["Retry-After"]))"""
            
            if results['results']['bindings'] == []:
                print(""+x+" not found")
            else:
                film.append(results['results']['bindings'][0]['film_label']['value'])
                director.append(results['results']['bindings'][0]['director_label']['value'])
                gender.append(results['results']['bindings'][0]['dir_gen_label']['value'])
                distributor.append(results['results']['bindings'][0]['distributor_label']['value'])
                    
            
    print(len(film))



wikidata_reconciliation(ciccio_prova)

#wikidata_reconciliation(title[100:200])
# Out:
# Dick Johnson Is Dead
# My Little Pony: A New Generation
# My Little Pony: A New Generation not found
# Sankofa
# Sankofa not found
# The Starling
# Je Suis Karl
# Je Suis Karl not found
# Confessions of an Invisible Girl
# Confessions of an Invisible Girl not found
# Europe's Most Dangerous Man: Otto Skorzeny in Spain
# Europe's Most Dangerous Man: Otto Skorzeny in Spain not found
# Intrusion
# Intrusion not found
# Avvai Shanmughi
# Avvai Shanmughi not found
# Go! Go! Cory Carson: Chrissy Takes the Wheel
# Go! Go! Cory Carson: Chrissy Takes the Wheel not found
# Jeans
# Jeans not found
# Minsara Kanavu
# Minsara Kanavu not found
# Grown Ups
# Dark Skies
# Paranoia
# Ankahi Kahaniya
# Ankahi Kahaniya not found
# The Father Who Moves Mountains
# The Father Who Moves Mountains not found
# The Stronghold
# The Stronghold not found
# Birth of the Dragon
# Jaws
# Jaws 2
# Jaws 3
# Jaws 3 not found
# Jaws: The Revenge
# My Heroes Were Cowboys
# My Heroes Were Cowboys not found
# Safe House
# Training Day
# InuYasha the Movie 2: The Castle Beyond the Looking Glass
# InuYasha the Movie 2: The Castle Beyond the Looking Glass not found
# InuYasha the Movie 3: Swords of an Honorable Ruler
# InuYasha the Movie 3: Swords of an Honorable Ruler not found
# InuYasha the Movie 4: Fire on the Mystic Island
# InuYasha the Movie 4: Fire on the Mystic Island not found
# InuYasha the Movie: Affections Touching Across Time
# InuYasha the Movie: Affections Touching Across Time not found
# Naruto Shippuden the Movie: Blood Prison
# Naruto Shippuden the Movie: Blood Prison not found
# Naruto Shippûden the Movie: Bonds
# Naruto Shippûden the Movie: Bonds not found
# Naruto Shippûden the Movie: The Will of Fire
# Naruto Shippûden the Movie: The Will of Fire not found
# Naruto Shippuden: The Movie
# Naruto Shippuden: The Movie not found
# Naruto Shippuden: The Movie: The Lost Tower
# Naruto Shippuden: The Movie: The Lost Tower not found
# Naruto the Movie 2: Legend of the Stone of Gelel
# Naruto the Movie 2: Legend of the Stone of Gelel not found
# Naruto the Movie 3: Guardians of the Crescent Moon Kingdom
# Naruto the Movie 3: Guardians of the Crescent Moon Kingdom not found
# Naruto the Movie: Ninja Clash in the Land of Snow
# Naruto the Movie: Ninja Clash in the Land of Snow not found
# Nightbooks
# Schumacher
# Schumacher not found
# A StoryBots Space Adventure
# A StoryBots Space Adventure not found
# King of Boys
# King of Boys not found
# You vs. Wild: Out Cold
# You vs. Wild: Out Cold not found
# Little Singham - Black Shadow
# Little Singham - Black Shadow not found
# Tughlaq Durbar
# Tughlaq Durbar not found
# Tughlaq Durbar (Telugu)
# Tughlaq Durbar (Telugu) not found
# Firedrake the Silver Dragon
# Firedrake the Silver Dragon not found
# Kate
# Omo Ghetto: the Saga
# Omo Ghetto: the Saga not found
# Prey
# Blood Brothers: Malcolm X & Muhammad Ali
# Blood Brothers: Malcolm X & Muhammad Ali not found
# Paradise Hills
# The Women and the Murderer
# The Women and the Murderer not found
# JJ+E
# JJ+E not found
# Show Dogs
# If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd
# If I Leave Here Tomorrow: A Film About Lynyrd Skynyrd not found
# Untold: Breaking Point
# Untold: Breaking Point not found
# Shadow Parties
# Shadow Parties not found
# Angamaly Diaries
# Angamaly Diaries not found
# A Champion Heart
# A Champion Heart not found
# Worth
# Worth not found
# Afterlife of the Party
# Anjaam
# Anjaam not found
# Bright Star
# Dhanak
# Final Account
# Final Account not found
# Gurgaon
# Gurgaon not found
# Here and There
# In the Cut
# Shikara
# Shikara not found
# A Cinderella Story
# Agatha Christie's Crooked House
# Agatha Christie's Crooked House not found
# An Unfinished Life
# Barbie Big City Big Dreams
# Barbie Big City Big Dreams not found
# Blade Runner: The Final Cut
# Blade Runner: The Final Cut not found
# Chappie
# Clear and Present Danger
# Cliffhanger
# Cold Mountain
# Crocodile Dundee in Los Angeles
# Dear John
# Do the Right Thing
# El patrón, radiografía de un crimen
# El patrón, radiografía de un crimen not found
# Extraction
# Freedom Writers
# Green Lantern
# House Party
# House Party 2
# House Party 3
# House Party 3 not found
# I Got the Hook Up
# In Too Deep
# Initial D
# Janoskians: Untold and Untrue
# Janoskians: Untold and Untrue not found
# Labyrinth
# Letters to Juliet
# Level 16
# Level 16 not found
# Love Don't Cost a Thing
# Love in a Puff
# Love in a Puff not found
# Mars Attacks!
# Marshall
# My Boss's Daughter
# Mystery Men
# Once Upon a Time in America
# Open Season 2
# Open Season 2 not found
# Osmosis Jones
# Osmosis Jones not found
# Poseidon
# Rhyme & Reason
# Same Kind of Different as Me
# School of Rock
# Snervous Tyler Oakley
# Snervous Tyler Oakley not found
# Tears of the Sun
# The Blue Lagoon
# The Golden Child
# The Guns of Navarone
# The Interview
# The Nutty Professor
# The Nutty Professor II: The Klumps
# The Nutty Professor II: The Klumps not found
# Welcome Home Roscoe Jenkins
# In the Line of Fire
# Untold: Crime & Penalties
# Untold: Crime & Penalties not found
# 2 Alone in Paris
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3776/2407291487.py in <module>
#      69
#      70
# ---> 71 wikidata_reconciliation(ciccio_prova)
#      72
#      73 #wikidata_reconciliation(title[100:200])
#
# ~\AppData\Local\Temp/ipykernel_3776/2407291487.py in wikidata_reconciliation(query)
#      50             sparql_wd.setReturnFormat(JSON)
#      51             # get the results
# ---> 52             results = sparql_wd.query().convert()
#      53             response = requests.head(wikidata_endpoint)
#      54             """if response.status_code == 429:
#
# ~\AppData\Roaming\Python\Python39\site-packages\SPARQLWrapper\Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1085                 raise EndPointInternalError(e.read())
#    1086             else:
# -> 1087                 raise e
#    1088
#    1089     def query(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\SPARQLWrapper\Wrapper.py in _query(self)
#    1071                 response = urlopener(request, timeout=self.timeout)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#    1075         except urllib.error.HTTPError as e:
#
# c:\Program Files\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# c:\Program Files\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# c:\Program Files\Python39\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# c:\Program Files\Python39\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# c:\Program Files\Python39\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# c:\Program Files\Python39\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
film = [] #facciamo un po' di liste che ci divertiamo
director = []
gender = []
distributor = []
score = [] 

p = pprint.PrettyPrinter(indent=1)
import urllib.error
from xml.etree.ElementPath import xpath_tokenizer_re

def wikidata_reconciliation(query):

    try:
    # get the endpoint API
        wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
        """ print("query = title[0:2]")
        print(query)
        print("film should be []")
        print(film) """

        for x in query:
            print(x)
            my_SPARQL_query = """
            SELECT ?film ?film_label ?director ?director_label ?dir_gen ?dir_gen_label ?distributor ?distributor_label ?review_score
            WHERE
            {
            # ?film wdt:P31 wd:Q11424 .
            # ?film rdfs:label """+'"'+ x +'"' +"""@en .
            # ?film rdfs:label ?film_label .
            FILTER(lang(?film_label) = 'en')
            # ?film wdt:P57 ?director . 
            # ?director rdfs:label ?director_label .    
            FILTER(lang(?director_label) = 'en')
            # ?director wdt:P21 ?dir_gen . 
            # ?dir_gen rdfs:label ?dir_gen_label .
            FILTER(lang(?dir_gen_label) = 'en')
            # ?film wdt:P750 ?distributor . 
            # ?distributor rdfs:label ?distributor_label .
            FILTER(lang(?distributor_label) = 'en')
            # ?film wdt:P444 ?review_score .
            }
            """
            # set the endpoint 
            sparql_wd = SPARQLWrapper(wikidata_endpoint)
            # set the query
            sparql_wd.setQuery(my_SPARQL_query)
            # set the returned format
            sparql_wd.setReturnFormat(JSON)
            # get the results
            
            results = sparql_wd.query().convert()

            if results['results']['bindings'] == []:
                print(""+x+" not found")
            else:
                film.append(results['results']['bindings'][0]['film_label']['value'])
                director.append(results['results']['bindings'][0]['director_label']['value'])
                gender.append(results['results']['bindings'][0]['dir_gen_label']['value'])
                distributor.append(results['results']['bindings'][0]['distributor_label']['value'])

    except urllib.error.HTTPError as e:
        print(e.headers)
        print(e.headers["retry-after"])
        time.sleep((int(e.headers["retry-after"])) + 1)
        error_title = query.index(film[-1])
        wikidata_reconciliation(query[error_title:])
            
    print(len(film))



wikidata_reconciliation(ciccio_prova)
# Out:
# Dick Johnson Is Dead
# My Little Pony: A New Generation
# My Little Pony: A New Generation not found
# Sankofa
# Sankofa not found
# The Starling
# Je Suis Karl
# Je Suis Karl not found
# Confessions of an Invisible Girl
# Confessions of an Invisible Girl not found
# Europe's Most Dangerous Man: Otto Skorzeny in Spain
# Europe's Most Dangerous Man: Otto Skorzeny in Spain not found
# Intrusion
# Intrusion not found
# Avvai Shanmughi
# Avvai Shanmughi not found
# Go! Go! Cory Carson: Chrissy Takes the Wheel
# Go! Go! Cory Carson: Chrissy Takes the Wheel not found
# Jeans
# Jeans not found
# Minsara Kanavu
# Minsara Kanavu not found
# Grown Ups
# Dark Skies
# Paranoia
# Ankahi Kahaniya
# Ankahi Kahaniya not found
# The Father Who Moves Mountains
# The Father Who Moves Mountains not found
# The Stronghold
# The Stronghold not found
# Birth of the Dragon
# Jaws
# 7

# %%
p = pprint.PrettyPrinter(indent=1)

def wikidata_reconciliation(query):

    ssl._create_default_https_context = ssl._create_unverified_context
    
    # get the endpoint API
    wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
    """ print("query = title[0:2]")
    print(query)
    print("film should be []")
    print(film) """

    for x in query:
        print(x)
        my_SPARQL_query = """
        SELECT ?film ?film_label ?director ?director_label ?dir_gen ?dir_gen_label ?distributor ?distributor_label ?review_score
        WHERE
        {
        # ?film wdt:P31 wd:Q11424 .
        # ?film rdfs:label """+'"'+ x +'"' +"""@en .
        # ?film rdfs:label ?film_label .
        FILTER(lang(?film_label) = 'en')
        # ?film wdt:P57 ?director . 
        # ?director rdfs:label ?director_label .    
        FILTER(lang(?director_label) = 'en')
        # ?director wdt:P21 ?dir_gen . 
        # ?dir_gen rdfs:label ?dir_gen_label .
        FILTER(lang(?dir_gen_label) = 'en')
        # ?film wdt:P750 ?distributor . 
        # ?distributor rdfs:label ?distributor_label .
        FILTER(lang(?distributor_label) = 'en')
        # ?film wdt:P444 ?review_score .
        }
        """
        # set the endpoint 
        sparql_wd = SPARQLWrapper(wikidata_endpoint)
        # set the query
        sparql_wd.setQuery(my_SPARQL_query)
        # set the returned format
        sparql_wd.setReturnFormat(JSON)
        # get the results
        results = sparql_wd.query().convert()
        # get response
        response = requests.head(wikidata_endpoint)
        print(response.status_code)
        if response.status_code != 200:
            p.pprint(response.headers)

    print(response.status_code)
    if response.status_code != 200:
            p.pprint(response.headers)
        
wikidata_reconciliation(title[0:140])
# Out:
# Dick Johnson Is Dead
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '16', 'x-cache': 'cp6013 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# My Little Pony: A New Generation
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'content-length': '21686397', 'age': '39', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Sankofa
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:34:33 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '14', 'x-cache': 'cp6009 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# The Starling
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:34:39 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1015', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6016 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Je Suis Karl
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '103', 'x-cache': 'cp6013 hit, cp6012 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# Confessions of an Invisible Girl
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:35:34 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '10', 'x-cache': 'cp6012 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Europe's Most Dangerous Man: Otto Skorzeny in Spain
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:36:00 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6012 miss, cp6012 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# Intrusion
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:36:07 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1016', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6014 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Avvai Shanmughi
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:36:15 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1004', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '8', 'x-cache': 'cp6014 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Go! Go! Cory Carson: Chrissy Takes the Wheel
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:36:20 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6015 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Jeans
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'content-length': '21686397', 'age': '183', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Minsara Kanavu
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '205', 'x-cache': 'cp6013 hit, cp6012 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# Grown Ups
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'content-length': '21686397', 'age': '205', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Dark Skies
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:37:11 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6011 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Paranoia
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:37:20 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1012', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '9', 'x-cache': 'cp6010 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Ankahi Kahaniya
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:37:25 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '5', 'x-cache': 'cp6011 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# The Father Who Moves Mountains
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'content-length': '21686397', 'age': '248', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# The Stronghold
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:37:54 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1004', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6015 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Birth of the Dragon
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:38:21 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '5', 'x-cache': 'cp6016 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Jaws
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:33:54 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '283', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Jaws 2
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:38:53 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '9', 'x-cache': 'cp6013 miss, cp6012 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# Jaws 3
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:38:53 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '9', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Jaws: The Revenge
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:39:21 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1007', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6011 miss, cp6012 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# My Heroes Were Cowboys
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:39:28 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1006', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6010 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Safe House
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:39:33 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1014', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6010 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Training Day
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:39:40 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1015', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '3', 'x-cache': 'cp6014 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# InuYasha the Movie 2: The Castle Beyond the Looking Glass
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:39:44 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1015', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6014 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# InuYasha the Movie 3: Swords of an Honorable Ruler
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:40:09 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1014', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6010 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# InuYasha the Movie 4: Fire on the Mystic Island
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:40:14 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1015', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6012 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# InuYasha the Movie: Affections Touching Across Time
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:38:53 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'content-length': '21882429', 'age': '90', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Naruto Shippuden the Movie: Blood Prison
# 200
# ...
# Kyaa Super Kool Hain Hum
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 09:54:51 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1013', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '295', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Kyo Kii... Main Jhuth Nahin Bolta
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:00:08 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1014', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '8', 'x-cache': 'cp6013 miss, cp6012 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6012"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '93.34.81.222', 'accept-ranges': 'bytes'}
# LSD: Love, Sex Aur Dhokha
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:00:08 GMT', 'content-type': 'application/rdf+xml', 'x-served-by': 'wdqs1014', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'content-encoding': 'gzip', 'vary': 'Accept, Accept-Encoding', 'age': '29', 'x-cache': 'cp6013 hit, cp6013 pass', 'x-cache-status': 'hit-local', 'server-timing': 'cache;desc="hit-local", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Mission Istaanbul: Darr Ke Aagey Jeet Hai
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:00:33 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1012', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '3', 'x-cache': 'cp6012 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Once Upon a Time in Mumbaai
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:00:39 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1012', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6009 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Once Upon a Time in Mumbai Dobaara!
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:01:04 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1012', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '4', 'x-cache': 'cp6012 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Ragini MMS
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:01:12 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21784413', 'x-served-by': 'wdqs1006', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '8', 'x-cache': 'cp6014 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# Ragini MMS 2
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:01:21 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21686397', 'x-served-by': 'wdqs1014', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '7', 'x-cache': 'cp6010 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# SAS: Rise of the Black Swan
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:01:49 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6015 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}
# 200
# {'server': 'nginx/1.14.2', 'date': 'Sat, 13 Aug 2022 10:01:49 GMT', 'content-type': 'application/rdf+xml', 'content-length': '21882429', 'x-served-by': 'wdqs1005', 'access-control-allow-origin': '*', 'cache-control': 'public, max-age=300', 'vary': 'Accept', 'age': '6', 'x-cache': 'cp6015 miss, cp6013 pass', 'x-cache-status': 'pass', 'server-timing': 'cache;desc="pass", host;desc="cp6013"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=13-Aug-2022;Path=/;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT, WMF-Last-Access-Global=13-Aug-2022;Path=/;Domain=.wikidata.org;HttpOnly;secure;Expires=Wed, 14 Sep 2022 00:00:00 GMT', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy': 'interest-cohort=(),ch-ua-arch=(self "intake-analytics.wikimedia.org"),ch-ua-bitness=(self "intake-analytics.wikimedia.org"),ch-ua-full-version-list=(self "intake-analytics.wikimedia.org"),ch-ua-model=(self "intake-analytics.wikimedia.org"),ch-ua-platform-version=(self "intake-analytics.wikimedia.org")', 'x-client-ip': '2001:b07:ab5:b408:f82d:8f5d:6c8:2fcf', 'accept-ranges': 'bytes'}

# %%
print(film)
# Out:
# ['Dick Johnson Is Dead', 'The Starling', 'Grown Ups', 'Dark Skies', 'Paranoia', 'Birth of the Dragon', 'Jaws']
