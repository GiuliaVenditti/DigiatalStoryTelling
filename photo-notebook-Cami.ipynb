# %%
import pandas as pd #make a set from photographers'name from wordpress dataset
photographer= set()
df = pd.read_csv("worldpressphotographer_update.csv")
df = df["photographer"]
for x in df:
    photographer.add(x)
df.head()
print(len(photographer))
# Out:
# 786

# %%
from bs4 import BeautifulSoup  #make a list of photograpies jsons quering artsy api 
import requests
import json
import pandas as pd
from requests.structures import CaseInsensitiveDict
#pp = pprint.PrettyPrinter(indent=1)

#html element that contains a list of selected photographers

html = '''<div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jkcvUH"><div display="flex" tabindex="-1" role="checkbox" aria-checked="false" disabled="" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP pXkah"><div disabled="" class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB gXQyHx"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Artists I follow (0)</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="true" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP eWRQyy"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB enjDws"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Alex Webb</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Alfred Eisenstaedt</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">André Kertész</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Antonio Bolfo</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Armando Arorizo</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Art Shay</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Baron Wolman</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Ben Davies</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Brassaï</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Brea Souders</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Bruce Alan Greene</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Bruce Davidson</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Chad Kleitsch</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Chen Ronghui 陈荣辉</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Chris Steele Perkins</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Christos J. Palios</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Claudine Doury</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Colin Jones</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Danny Lyon</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">David Burdeny</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">David Burnett</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">David Darby, ASC</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">David Silver</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">David Yarrow</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Dominic Nahr</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Dorothea Lange</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">E.K. Waller</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Edouard Elias</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Elliot Erwitt</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Elliott Erwitt</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Erich Hartmann</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Ernest Withers</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Eve Arnold</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Evgenia Arbugaeva</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Gideon Mendel</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Gjon Mili</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Globe Photo Archives</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Gordon Parks</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Harry Benson</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Henri Cartier-Bresson</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Henri Dauman</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Herbert List</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Inge Morath</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Jacob A. Riis</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Jamel Shabazz</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">James Lewin</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Jan Banning</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Jeffrey Mayer</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Jimmy Nelson</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">John Migicovsky</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Keith Skelton</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Keris Salmon</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Larry Burrows</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Larry Cook</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Lauren Greenfield</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Leonard Freed</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Louis Kravitz</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Manolo Marquez</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Marc Riboud</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Margaret Bourke-White</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Masao Gozu</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Michael O'Neill</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Mitchell Funk</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Murray Garrett</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Mário Macilau</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Pamela Littky</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Paul Fusco</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Paul Nicklen</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Poulomi Basu</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Prabir Purkayastha</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Raffaela Mariniello</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Raul Roa</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Richard E. Aaron</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Robert Capa</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Robert Doisneau</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Robert Funk</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Robert Polidori</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Ron Galella</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Sebastian Copeland</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Sebastião Salgado</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Sergey Melnitchenko</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Shane Lavalette</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Sim Posen</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Slim Aarons</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Steve McCurry</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Steve Schapiro</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Susan Meiselas</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Terry O'Neill</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Thomas Hoepker</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Tom Kiefer</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Unknown</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Vivian Maier</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">W. Eugene Smith</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Walter Iooss, Jr.</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Wang Tong</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Weegee</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">Wesaam Al-Badry</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">William Dalrymple</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">William Klein</div></div></div><div display="flex" tabindex="0" role="checkbox" aria-checked="false" class="Box-sc-15se88d-0 Checkbox__Container-j97vg8-0 bqEkyP cKGIDN"><div class="Box-sc-15se88d-0 Check__Container-mkx5fy-0 hxKyvB HabUY"><svg aria-hidden="true" fill="currentColor" viewBox="0 0 18 18" height="18px" width="18px" class="Icon-sc-1eovgys-0 kAqktO"><title>Check</title><path d="M6.936 12.206l7.64-7.63.848.849-8.492 8.48-4.248-4.282.852-.846z" fill="currentColor" fill-rule="nonzero"></path></svg></div><div display="flex" class="Box-sc-15se88d-0 Flex-cw39ct-0 jDlIOQ"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dNbjpX">robin hammond</div></div></div><button text-decoration="underline" cursor="pointer" type="button" class="Clickable-sc-10cr82y-0 jPuBMs"><div font-family="sans" class="Box-sc-15se88d-0 Text-sc-18gcpao-0  dWIigx">Hide</div></button></div>'''

soup = BeautifulSoup(html, "html.parser")

data = [element.text for element in soup.find_all("div", "dNbjpX")]

data.remove(data[0])

photogr_set = set() #make the list into a set (can this be skipped?)
for c in data:
    photogr_set.add(c)

photographer.update(photogr_set)#merge the sets

print(len(photographer))
# Out:
# 881

# %%
phot_json_list = list()
phot_json_list1 = list()
phot_json_list2 = list()
phot_json_list3 = list()

for i in photographer:  #use the set of the databases to query artsy api (we obtain the jsons of artworks not the artists) and save the result locally
    query = i.replace(" ", "+")
    url = "https://api.artsy.net/api/search?q={}".format(query)
    headers = CaseInsensitiveDict()
    headers["X-Xapp-Token"] = "eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MjM0ZGVhOTczMGVkMjAwMGNiNzI0YmYiLCJleHAiOjE2NDgyMzY4NDEsImlhdCI6MTY0NzYzMjA0MSwiYXVkIjoiNjIzNGRlYTk3MzBlZDIwMDBjYjcyNGJmIiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYyMzRkZWE5M2IyMmQwMDAwZGRkYjRhYSJ9.U74H5GIBsVS9zxG1hZ086W1UoyZy10ZG7ZFDKraKOD8"
    resp = requests.get(url, headers=headers)
    resp_json= resp.json()
    if len(phot_json_list)< 200:
        phot_json_list.append(resp_json)
        json.dump(phot_json_list, open("phot_json_list1.json", 'w'), indent=2)
    elif len(phot_json_list1)< 200:
        phot_json_list1.append(resp_json)
        json.dump(phot_json_list, open("phot_json_list2.json", 'w'), indent=2)
    elif len(phot_json_list2)< 200:
        phot_json_list2.append(resp_json)
        json.dump(phot_json_list, open("phot_json_list3.json", 'w'), indent=2)
    elif len(phot_json_list3)< 290:
        phot_json_list3.append(resp_json)
        json.dump(phot_json_list, open("phot_json_list4.json", 'w'), indent=2)


#print(phot_json_list)

# %%
for artwork in resp_json["_embedded"]["results"]: # make two separate lists for the artist json and its exibhits
    print(artwork['_links']["self"]["href"])
